# %% [markdown]
# Функция нахождения корня

# %%
def sqrt(a):
    l = 0
    if a >= 1:
        r = a
    else:
        r = 1

    while r - l > 10 ** -5:
        m = (r + l) / 2
        if m ** 2 < a:
            l = m
        else:
            r = m
    return l

# %% [markdown]
# Читаем данные из файла

# %%
def create1List():
    lst = []
    with open("CdSe_CdZnS Core_Shell.txt", "r", encoding="utf-8") as f:
        lines = f.readlines()
        for line in lines:
            lst.append(float(line.split()[0].replace(',', '.')))
    return lst


def create2List():
    lst = []
    with open("CdSe_CdZnS Core_Shell.txt", "r", encoding="utf-8") as f:
        lines = f.readlines()
        for line in lines:
            lst.append(float(line.split()[1].replace(',', '.')))
    return lst

# %% [markdown]
# Функция нахождения среднего отколнения

# %%
def averageDeviation(lst, avx):
    summ = 0
    for x in lst:
        summ += abs(x - avx)
    return summ / len(lst)

# %% [markdown]
# Функция нахождения среднеквадратичного отклонения

# %%
def standardDeviation(lst, avx):
    summ = 0
    for x in lst:
        summ += (x - avx)**2
    return sqrt(summ / len(lst))

# %% [markdown]
# Присваиваем значения переменным

# %%
lst1 = create1List()
lst2 = create2List()
avx1 = sum(lst1) / len(lst1)
avx2 = sum(lst2) / len(lst2)

# %% [markdown]
# Проверяем, всё ли так присвоилось

# %%
print(lst1)
print(avx1)
# Out:
# [500.349, 501.123, 501.897, 502.671, 503.445, 504.219, 504.992, 505.766, 506.539, 507.312, 508.086, 508.859, 509.632, 510.405, 511.178, 511.951, 512.724, 513.497, 514.269, 515.042, 515.815, 516.587, 517.36, 518.132, 518.904, 519.676, 520.448, 521.22, 521.992, 522.764, 523.536, 524.308, 525.079, 525.851, 526.622, 527.394, 528.165, 528.936, 529.708, 530.479, 531.25, 532.021, 532.792, 533.562, 534.333, 535.104, 535.874, 536.645, 537.415, 538.186, 538.956, 539.726, 540.496, 541.266, 542.036, 542.806, 543.576, 544.346, 545.116, 545.885, 546.655, 547.424, 548.194, 548.963, 549.732, 550.501, 551.27, 552.039, 552.808, 553.577, 554.346, 555.115, 555.883, 556.652, 557.42, 558.189, 558.957, 559.725, 560.493, 561.262, 562.03, 562.798, 563.565, 564.333, 565.101, 565.869, 566.636, 567.404, 568.171, 568.938, 569.706, 570.473, 571.24, 572.007, 572.774, 573.541, 574.308, 575.074, 575.841, 576.608, 577.374, 578.141, 578.907, 579.673, 580.44, 581.206, 581.972, 582.738, 583.504, 584.27, 585.035, 585.801, 586.567, 587.332, 588.098, 588.863, 589.628, 590.394, 591.159, 591.924, 592.689, 593.454, 594.219, 594.983, 595.748, 596.513, 597.277, 598.042, 598.806, 599.57, 600.335, 601.099, 601.863, 602.627, 603.391, 604.155, 604.919, 605.682, 606.446, 607.21, 607.973, 608.737, 609.5, 610.263, 611.026, 611.79, 612.553, 613.316, 614.078, 614.841, 615.604, 616.367, 617.129, 617.892, 618.654, 619.417, 620.179, 620.941, 621.703, 622.465, 623.227, 623.989, 624.751, 625.513, 626.275, 627.036, 627.798, 628.559, 629.321, 630.082, 630.843, 631.604, 632.365, 633.127, 633.887, 634.648, 635.409, 636.17, 636.93, 637.691, 638.452, 639.212, 639.972, 640.733, 641.493, 642.253, 643.013, 643.773, 644.533, 645.293, 646.052, 646.812, 647.572, 648.331, 649.09, 649.85, 650.609, 651.368
.75, 4.75, 8.75, 3.75, 5.75, -0.25, -3.25, 7.75, 6.75, -3.25, 5.75, -0.25, 2.75, 5.75, 2.75, 0.75, 2.75, 5.75, 4.75, 5.75, 2.75, 5.75, -1.25, 5.75, 6.75, 1.75, 0.75, 4.75, 0.75, 8.75, 3.75, 4.75, 2.75, 4.75, 6.75, 7.75, -5.25, 2.75, 8.75, 4.75, 10.75, 10.75, 13.75, 5.75, 4.75, 15.75, 11.75, 17.75, 19.75, 11.75, 15.75, 18.75, 17.75, 19.75, 16.75, 21.75, 22.75, 36.75, 39.75, 38.75, 29.75, 35.75, 33.75, 43.75, 50.75, 45.75, 44.75, 53.75, 56.75, 53.75, 59.75, 61.75, 65.75, 70.75, 68.75, 64.75, 70.75, 75.75, 62.75, 70.75, 59.75, 63.75, 66.75, 62.75, 61.75, 64.75, 64.75, 46.75, 50.75, 54.75, 50.75, 44.75, 44.75, 42.75, 42.75, 38.75, 34.75, 33.75, 31.75, 30.75, 25.75, 30.75, 16.75, 15.75, 20.75, 28.75, 23.75, 12.75, 12.75, 15.75, 11.75, 8.75, 10.75, 12.75, 9.75, 8.75, 6.75, 12.75, 11.75, 9.75, 5.75, 3.75, 7.75, 6.75, 7.75, 6.75, 10.75, 7.75, 2.75, 2.75, 7.75, 6.75, 6.75, 0.75, 2.75, 11.75, 5.75, 7.75, 4.75, 4.75, 0.75, -1.25, 8.75, 4.75, 5.75, 2.75, 0.75, 2.75, -0.25, 3.75, -2.25, 0.75, 3.75, 4.75, -1.25, -4.25, 3.75, 0.75, 1.75, -7.25, 5.75, -1.25, 5.75, 1.75, -2.25, 0.75, 1.75, 0.75, 4.75, -2.25, -2.25, 0.75, 3.75, -1.25, 2.75, -0.25, 4.75, -0.25, -2.25, 1.75, 5.75, 7.75, -6.25, 2.75, 0.75, 3.75, -0.25, 3.75, -3.25, -4.25, -1.25, 0.75, 2.75, 8.75, -0.25, -7.25, -0.25, 2.75, -2.25, 0.75, 5.75, 1.75, -5.25, 4.75, 1.75, 4.75, -1.25, -3.25, 1.75, -0.25, 4.75, 0.75, 2.75, 3.75, -4.25, -0.25, -1.25, 1.75, 0.75, 2.75, -0.25, 1.75, -1.25, -0.25, -4.25, 2.75, 0.75, -1.25, -2.25, 2.75, -3.25, 1.75, -3.25, -3.25, -3.25, 4.75, 2.75, -2.25, -1.25, -4.25, 0.75, 1.75, 2.75, -0.25, -0.25, 1.75, -1.25, 1.75, -1.25, -9.25, 0.75, -2.25, -1.25, 7.75, -2.25, 5.75, -0.25, -1.25, 3.75, 0.75, -0.25, 2.75, -0.25, 0.75, -1.25, 0.75, -2.25, -3.25, 0.75, -1.25]
# 8.506962025316456

# %% [markdown]
# Ответы:

# %%
print("Среднее отклонение первых чисел: ", averageDeviation(lst1, avx1))
print("Среднеквадратичное отклонение первых чисел: ", standardDeviation(lst1, avx1))
# Out:
# Среднее отклонение первых чисел:  74.96879156545424
# Среднеквадратичное отклонение первых чисел:  86.5664637409524

# %%
print("Среднее отклонение вторых чисел: ", averageDeviation(lst2, avx2))
print("Среднеквадратичное отклонение вторых чисел: ", standardDeviation(lst2, avx2))
# Out:
# Среднее отклонение вторых чисел:  10.765287614164432
# Среднеквадратичное отклонение вторых чисел:  16.581565599503428
